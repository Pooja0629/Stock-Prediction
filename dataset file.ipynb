# %%
import yfinance as yf

tcs = yf.download("TCS.NS", period="max")
tcs.to_csv("TCS.csv")

tcs.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2316\1671149261.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tcs = yf.download("TCS.NS", period="max")
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open  Volume
# Ticker         TCS.NS     TCS.NS     TCS.NS     TCS.NS  TCS.NS
# Date
# 2002-08-12  26.297937  26.496662  25.652080  25.652080  212976
# 2002-08-13  25.941881  26.753343  25.751437  26.331052  153576
# 2002-08-14  24.153366  25.999851  23.664832  25.999851  822776
# 2002-08-15  24.153366  24.153366  24.153366  24.153366       0
# 2002-08-16  24.095409  25.171837  23.681399  24.029169  811856
